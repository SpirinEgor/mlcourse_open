# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from matplotlib import pyplot as plt
plt.style.use('ggplot')

import seaborn as sns
import os
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook
import pickle as pkl
from collections import defaultdict

from scipy.sparse import csr_matrix, hstack, vstack
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb
import lightgbm as lgbm
import catboost as cb

# %%
PATH_TO_DATA = ('./data')
train_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_sessions.csv'), index_col='session_id')
test_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_sessions.csv'), index_col='session_id')

# %%
site_dict = pkl.load(open('./data/site_dic.pkl', 'rb'))
site_dict_inv = defaultdict(str, [(v, k) for (k, v) in site_dict.items()])

# %%
sites = ['site%s' % i for i in np.arange(1, 11)]
train_df.fillna(0, inplace=True)
train_df[sites] = train_df[sites].astype(int)
train_df[sites]
# Out:
#             site1  site2  site3  site4  site5  site6  site7  site8  site9  \
# session_id
# 1             718      0      0      0      0      0      0      0      0
# 2             890    941   3847    941    942   3846   3847   3846   1516
# 3           14769     39  14768  14769     37     39  14768  14768  14768
# 4             782    782    782    782    782    782    782    782    782
# 5              22    177    175    178    177    178    175    177    177
# 6             570     21    570     21     21      0      0      0      0
# 7             803     23   5956  17513     37     21    803  17514  17514
# 8              22     21     29   5041  14422     23     21   5041  14421
# 9             668    940    942    941    941    942    940     23     21
# 10           3700    229    570     21    229     21     21     21   2336
# 11            229   1500     33   1500    391     35     29   2276  40305
# 12             37     39   3592    890     35     29     22     30     33
# 13             23    747     23    749     23     21    752     55     56
# 14            262    322    625     52     37    152     21   2164   2164
# 15           2883   2945    167    167    167     21      3    229     21
# 16          28395    248    728   3364   3362   1434     30    102    727
# 17             63    167    167    359    167    167    167    360    363
# 18            178    343    167    270    167   2726   2727   2725   2724
# 19          22736  22736  22736  22736  22736  22736  22736  22736  22736
# 20             33     35     52     23     29   2439   2439     29    803
# 21            676    812    982     39    812     23    677  22616     63
# 22             21     21     22     23     22     21     21     23     63
# 23            782    782    782    782    782    782    780    780    782
# 24            812      0      0      0      0      0      0      0      0
# 25             23  16249  16249     66    939    939    229     21     23
# 26             23     22  25013  25013   3430  25013     66     63  25013
# 27             23    291   2894   1643   2893   2893    291   2896     48
# 28            780    780    780    780    780    780    782    780    780
# 29           6289  27963  18257  27962     21     23  27961  27954  27954
# 30           2740    262    539    322    148    539    293      0      0
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 253532      14678  14677    167    167    167      3    384    167  14677
# 253533         22   3346     23  12382  12382  12382  12382     38  12382
# 253534          8   1996   1996     32   1997   1998   1996     30   1997
# 253535       2428   2428   2428   2428   2428   2428   2428   2428   2428
# 253536         76     76     82     80     80     76     77     76     80
# 253537        812    173    173     21     21    830     21     23    830
# 253538        306     56     55      0      0      0      0      0      0
# 253539         29   2097     33     29     35     29     22   2097     35
# 253540       2050   2856    570     29  22935   2856  18544  22935     29
# 253541        782    782    780    780    780    780    778    780    782
# 253542       1514    855   1518   1524   1520   1517   1524   1524   1519
# 253543        912     32     35   1647    912   2896     29     21   1645
# 253544       9738   9740   9738   9738   9740   9738   9740   3043     32
# 253545       6003   6003   6003   6003   6003   6003   6003   6003   6003
# 253546       4368  17744  17743     29     33     35   4368     37    948
# 253547         39   8556   1039    812    570   1039    774    812    167
# 253548        677    812    812    880    677    616    812    616    812
# 253549          3      8      3      4   3303      6     14      8     14
# 253550         77     75     77     75     55     56     55     76     75
# 253551       1039    812   1039    774   1039    774   1039    774   1039
# 253552        677    812    812    774     22    570    812    570    570
# 253553        778    780    780    778    780    778    780    780    778
# 253554      23797   1171      3      3      8      8      3  25722  25723
# 253555         71     29    570     29      3     29   5586   5587   5587
# 253556       9041    291     23     52     23   2371   2371   2371     52
# 253557       3474   3474    141   2428    106   2428   2428   2428   2428
# 253558      12727  12727   2215     38   2215     23  25444   2215     23
# 253559       2661  15004   5562   5562   5562      0      0      0      0
# 253560        812    676    814     22     39    812    814    570     22
# 253561      34942   1429  34942     29     30  34942   5779     30     35
#
#             site10
# session_id
# 1                0
# 2             1518
# 3            14768
# 4              782
# 5              178
# 6                0
# 7            17514
# 8            14421
# 9               22
# 10            2044
# 11              23
# 12            3592
# 13              55
# 14              30
# 15              76
# 16           28396
# 17             362
# 18            2732
# 19           22736
# 20              23
# 21             679
# 22               0
# 23             782
# 24               0
# 25            7270
# 26           25013
# 27             291
# 28             780
# 29           27960
# 30               0
# ...            ...
# 253532       14678
# 253533       12382
# 253534        1998
# 253535        2428
# 253536          80
# 253537          22
# 253538           0
# 253539          33
# 253540       22935
# 253541         780
# 253542        1524
# 253543          21
# 253544        9738
# 253545           0
# 253546         959
# 253547         167
# 253548         677
# 253549       20488
# 253550          80
# 253551           0
# 253552         570
# 253553         780
# 253554           4
# 253555        5587
# 253556          52
# 253557         148
# 253558          21
# 253559           0
# 253560         570
# 253561          33
#
# [253561 rows x 10 columns]

# %%
site_name = [site + '_name' for site in sites]

def is_ip(ip):
    spl = ip.split('.')
    if len(spl) != 4:
        return False
    for s in spl:
        if not s.isdigit():
            return False
    return True

def convert(x):
    if is_ip(x):
        return x
    elif x != '':
        return x.split('.')[-2]
    else:
        return '-'

for site in tqdm_notebook(sites):
    train_df[site + '_name'] = train_df[site].apply(lambda x: site_dict_inv[x])
    test_df[site + '_name'] = test_df[site].apply(lambda x: site_dict_inv[x])
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "/home/voudy/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/voudy/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/voudy/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-2023b0a956b7> in <module>()
#      20 for site in tqdm_notebook(sites):
#      21     train_df[site + '_name'] = train_df[site].apply(lambda x: site_dict_inv[x])
# ---> 22     test_df[site + '_name'] = test_df[site].apply(lambda x: site_dict_inv[x])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-2023b0a956b7> in <lambda>(x)
#      20 for site in tqdm_notebook(sites):
#      21     train_df[site + '_name'] = train_df[site].apply(lambda x: site_dict_inv[x])
# ---> 22     test_df[site + '_name'] = test_df[site].apply(lambda x: site_dict_inv[x])
#
# KeyboardInterrupt:

# %%
train_df[site_name]
# Out:
#                         site1_name      site2_name      site3_name  \
# session_id
# 1                        microsoft               -               -
# 2                           google          google          google
# 3                       googleapis          google      googleapis
# 4                       annotathon      annotathon      annotathon
# 5                           google       wikipedia       wikimedia
# 6                           google          google          google
# 7                           google          google         twitter
# 8                           google          google        facebook
# 9                           google          google          google
# 10                              gc          google          google
# 11                          google      caradisiac        facebook
# 12                         twitter          google        dspsport
# 13                          google  openclassrooms          google
# 14                          dotomi          simpli        comodoca
# 15                             fff             fff            bing
# 16              worldcup-in-brazil       sharethis              wp
# 17                       microsoft            bing            bing
# 18                       wikimedia       wikipedia            bing
# 19                        radiorva        radiorva        radiorva
# 20                        facebook        facebook          google
# 21                         youtube          google           gmail
# 22                          google          google          google
# 23                      annotathon      annotathon      annotathon
# 24                          google               -               -
# 25                          google            apec            apec
# 26                          google          google           olark
# 27                          google         iadvize       boulanger
# 28                             nih             nih             nih
# 29                              qq              qq              qq
# 30          mediapostcommunication          dotomi           adgrx
# ...                            ...             ...             ...
# 253532                     wemfbox         letemps            bing
# 253533                      google         dropbox          google
# 253534                      omtrdc             msn             msn
# 253535                       lemde           lemde           lemde
# 253536                     youtube         youtube     googlevideo
# 253537                      google        facebook        facebook
# 253538                   microsoft          google          google
# 253539                    facebook           4ever        facebook
# 253540                      makazi          ad-sys          google
# 253541                  annotathon      annotathon             nih
# 253542                   leboncoin       leboncoin  193.164.196.60
# 253543                 pagesjaunes        facebook        facebook
# 253544                vente-privee    vente-privee    vente-privee
# 253545                    symantec        symantec        symantec
# 253546                      tumblr  lesjoiesducode        ljdchost
# 253547                      google            ruvr          google
# 253548                      google          google          google
# 253549                        live          omtrdc            live
# 253550                       ytimg           ytimg           ytimg
# 253551                      google          google          google
# 253552                      google          google          google
# 253553                         nih             nih             nih
# 253554                  cloudfront         hotmail            live
# 253555                   microsoft        facebook          google
# 253556                      macway         iadvize          google
# 253557                     cedexis         cedexis         leguide
# 253558                      orange          orange        mythings
# 253559                   r-project              ac            ibcp
# 253560                      google         youtube          google
# 253561                    embauche     pagesjaunes        embauche
#
#                 site4_name      site5_name      site6_name      site7_name  \
# session_id
# 1                        -               -               -               -
# 2                   google          google          google          google
# 3               googleapis         twitter          google      googleapis
# 4               annotathon      annotathon      annotathon      annotathon
# 5                wikimedia       wikipedia       wikimedia       wikimedia
# 6                   google          google               -               -
# 7              html5doctor         twitter          google          google
# 8                     ztat         zalando          google          google
# 9                   google          google          google          google
# 10                  google          google          google          google
# 11              caradisiac          ezakus        facebook        facebook
# 12                  google        facebook        facebook          google
# 13              cloudfront          google          google      googleapis
# 14                  google         twitter     everesttech          google
# 15                    bing            bing          google            live
# 16            staticflickr    staticflickr        gravatar         twitter
# 17                    abmr            bing            bing            bing
# 18                    bing            bing       microsoft       microsoft
# 19                radiorva        radiorva        radiorva        radiorva
# 20                  google        facebook       w3schools       w3schools
# 21                  google          google          google          google
# 22                  google          google          google          google
# 23              annotathon      annotathon      annotathon             nih
# 24                       -               -               -               -
# 25               microsoft             msn             msn          google
# 26                   olark           olark           olark       microsoft
# 27              cloudfront       boulanger       boulanger         iadvize
# 28                     nih             nih             nih      annotathon
# 29                      qq          google          google            qyer
# 30                  simpli        tradelab           adgrx        newrelic
# ...                    ...             ...             ...             ...
# 253532                bing            bing            live            bing
# 253533       dropboxstatic   dropboxstatic   dropboxstatic   dropboxstatic
# 253534            facebook             msn             msn             msn
# 253535               lemde           lemde           lemde           lemde
# 253536             youtube         youtube         youtube           ytimg
# 253537              google          google          google          google
# 253538                   -               -               -               -
# 253539            facebook        facebook        facebook          google
# 253540            facebook         pub-fit          ad-sys         batanga
# 253541                 nih             nih             nih             nih
# 253542      193.164.197.60  193.164.196.50  193.164.197.50  193.164.197.60
# 253543         pagesjaunes     pagesjaunes        ip-label        facebook
# 253544        vente-privee    vente-privee    vente-privee    vente-privee
# 253545            symantec        symantec        symantec        symantec
# 253546            facebook        facebook        facebook          tumblr
# 253547              google          google          google          google
# 253548           microsoft          google          google          google
# 253549                live            live            live            live
# 253550               ytimg          google          google          google
# 253551              google          google          google          google
# 253552              google          google          google          google
# 253553                 nih             nih             nih             nih
# 253554                live          omtrdc          omtrdc            live
# 253555            facebook            live        facebook        xboxlive
# 253556              google          google          python          python
# 253557               lemde        gravatar           lemde           lemde
# 253558          googleapis        mythings          google        mythings
# 253559                ibcp            ibcp               -               -
# 253560              google          google          google          google
# 253561            facebook         twitter        embauche           mappy
#
#                 site8_name      site9_name     site10_name
# session_id
# 1                        -               -               -
# 2                   google  193.164.197.30  193.164.196.60
# 3               googleapis      googleapis      googleapis
# 4               annotathon      annotathon      annotathon
# 5                wikipedia       wikipedia       wikimedia
# 6                        -               -               -
# 7            designvegetal   designvegetal   designvegetal
# 8                     ztat            ztat            ztat
# 9                   google          google          google
# 10                  google        ad6media        ad6media
# 11           starfieldtech          codizy          google
# 12                 twitter        facebook        dspsport
# 13                  google          google          google
# 14                areaprog        areaprog         twitter
# 15                  google          google         youtube
# 16                      wp              wp            fifa
# 17                    bing            bing            bing
# 18               microsoft       microsoft       microsoft
# 19                radiorva        radiorva        radiorva
# 20                facebook          google          google
# 21                  google       microsoft          google
# 22                  google       microsoft               -
# 23                     nih      annotathon      annotathon
# 24                       -               -               -
# 25                  google          google            apec
# 26               microsoft           olark           olark
# 27                ip-label        digicert         iadvize
# 28                     nih             nih             nih
# 29                    qyer            qyer            qyer
# 30                       -               -               -
# ...                    ...             ...             ...
# 253532                bing         letemps         wemfbox
# 253533          googleapis   dropboxstatic   dropboxstatic
# 253534             twitter             msn             msn
# 253535               lemde           lemde           lemde
# 253536             youtube         youtube         youtube
# 253537              google          google          google
# 253538                   -               -               -
# 253539               4ever        facebook        facebook
# 253540             pub-fit        facebook         pub-fit
# 253541                 nih      annotathon             nih
# 253542      193.164.197.60  193.164.196.40  193.164.197.60
# 253543              google     pagesjaunes          google
# 253544          cloudfront        facebook    vente-privee
# 253545            symantec        symantec               -
# 253546             twitter          oracle          oracle
# 253547              google            bing            bing
# 253548              google          google          google
# 253549              omtrdc            live            live
# 253550             youtube           ytimg         youtube
# 253551              google          google               -
# 253552              google          google          google
# 253553                 nih             nih             nih
# 253554                asos    asosservices            live
# 253555                xbox            xbox            xbox
# 253556              python          google          google
# 253557               lemde           lemde        tradelab
# 253558            mythings          google          google
# 253559                   -               -               -
# 253560              google          google          google
# 253561             twitter        facebook        facebook
#
# [253561 rows x 10 columns]

# %%
def is_ip(ip):
    spl = ip.split('.')
    if len(spl) != 4:
        return False
    for s in spl:
        if not s.isdigit():
            return False
    return True

[i for i in site_dict.keys() if is_ip(i)]
# Out:
# ['193.50.234.35',
#  '83.206.13.2',
#  '91.121.134.14',
#  '37.59.49.196',
#  '83.169.83.154',
#  '162.38.181.25',
#  '69.195.124.152',
#  '210.156.129.164',
#  '202.183.63.213',
#  '176.58.127.102',
#  '83.206.219.162',
#  '198.251.79.228',
#  '173.236.101.58',
#  '128.101.105.82',
#  '178.255.153.13',
#  '115.30.191.21',
#  '37.252.230.18',
#  '87.98.128.200',
#  '85.17.77.13',
#  '5.9.139.3',
#  '79.98.96.110',
#  '193.164.196.40',
#  '74.50.147.105',
#  '217.146.14.4',
#  '130.209.15.9',
#  '203.112.63.12',
#  '103.1.187.206',
#  '202.183.54.12',
#  '199.167.151.66',
#  '46.28.49.180',
#  '87.230.83.56',
#  '37.59.38.219',
#  '218.47.39.195',
#  '78.24.130.6',
#  '5.9.138.194',
#  '5.135.140.211',
#  '85.31.208.126',
#  '178.79.162.68',
#  '202.183.63.208',
#  '50.18.191.15',
#  '195.158.240.48',
#  '66.70.56.43',
#  '62.75.236.44',
#  '193.164.196.60',
#  '85.214.84.91',
#  '193.164.197.30',
#  '176.58.127.107',
#  '206.128.127.131',
#  '91.121.97.162',
#  '94.23.236.222',
#  '193.164.196.50',
#  '37.252.230.26',
#  '59.146.77.13',
#  '50.18.122.28',
#  '65.54.113.26',
#  '88.159.162.66',
#  '66.147.244.57',
#  '178.75.164.191',
#  '210.128.81.133',
#  '95.211.184.115',
#  '37.252.230.24',
#  '46.105.57.81',
#  '94.23.23.208',
#  '198.101.200.156',
#  '208.74.204.114',
#  '203.141.205.180',
#  '60.45.63.26',
#  '188.165.40.164',
#  '193.164.197.50',
#  '162.38.101.55',
#  '37.252.230.22',
#  '173.192.5.118',
#  '37.252.230.27',
#  '178.33.227.102',
#  '162.218.115.228',
#  '188.138.10.213',
#  '219.117.218.85',
#  '178.33.231.59',
#  '60.33.230.11',
#  '37.252.248.77',
#  '37.252.253.6',
#  '116.193.97.222',
#  '160.92.123.193',
#  '210.167.76.204',
#  '78.116.39.212',
#  '178.79.183.159',
#  '37.252.232.3',
#  '212.83.158.208',
#  '193.164.197.60',
#  '93.93.190.243',
#  '188.165.239.57',
#  '204.10.32.68',
#  '37.252.232.2',
#  '92.113.35.53',
#  '193.164.197.40',
#  '193.164.196.30',
#  '91.121.182.20',
#  '210.157.212.145',
#  '80.254.191.189',
#  '143.127.102.40',
#  '213.30.164.213',
#  '188.165.255.70',
#  '67.53.48.2']
